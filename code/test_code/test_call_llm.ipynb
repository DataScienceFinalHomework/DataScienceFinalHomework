# %% [markdown]
# ## Test for call_llm.py

# %%
"""
The function prototype, parameters and return are here

Prototype:
    async def call_llm(prompt_system, prompt_user, session, RETRY_DELAY = 2, RETRY_ATTEMPTS = 3, timeout = 20, model_used = "deepseek-ai/DeepSeek-V3"):
Parameters:
    prompt_system: a string, the prompt needed to be post to LLM
        example: You are a expert in Computer Science
    prompt_user: a string, the prompt needed to be post to LLM
        example: explain what is data science in Chinese
    session: ...
    RETRY_DELAY: The time to delay if happens any error, defalut to 2
    RETRY_ATTEMPTS: The max times to delay if happens any error, defalut to 3
    timeout: The longest time to timeout
    model_used: The model used, defalut to deepseek-ai/DeepSeek-V3
Return:
    a tuple of (explanation, input_tokens, output_tokens)
    explanation: The result of LLM return

"""
# Out:
# '\nThe function prototype, parameters and return are here\n\nPrototype:\n    async def call_llm(prompt_system, prompt_user, session, RETRY_DELAY = 2, RETRY_ATTEMPTS = 3, timeout = 20, model_used = "deepseek-ai/DeepSeek-V3"):\nParameters:\n    prompt_system: a string, the prompt needed to be post to LLM\n        example: You are a expert in Computer Science\n    prompt_user: a string, the prompt needed to be post to LLM\n        example: explain what is data science in Chinese\n    session: ...\n    RETRY_DELAY: The time to delay if happens any error, defalut to 2\n    RETRY_ATTEMPTS: The max times to delay if happens any error, defalut to 3\n    timeout: The longest time to timeout\n    model_used: The model used, defalut to deepseek-ai/DeepSeek-V3\nReturn:\n    a tuple of (explanation, input_tokens, output_tokens)\n    explanation: The result of LLM return\n\n'

# %%
import sys
import os

# 获取当前 notebook 所在目录的上一级目录
parent_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))

if parent_dir not in sys.path:
    sys.path.append(parent_dir)

# 使用显式导入避免命名冲突
from CallLLM import call_llm, ReadInAPI

# %%
import asyncio
import aiohttp
prompt_system = "你是一个研究数据科学的专家"
prompt_user= "用简体中文详细讲解什么是数据科学"
MAX_CONCURRENCY = 100
semaphore = asyncio.Semaphore(MAX_CONCURRENCY)
async with aiohttp.ClientSession(
    connector=aiohttp.TCPConnector(limit=MAX_CONCURRENCY),
    timeout=aiohttp.ClientTimeout(total=300)
) as session:
    tasks = [call_llm(prompt_system, prompt_user, session, model_used = "Qwen/Qwen3.5-9B", timeout = 180)]
    results = await asyncio.gather(*tasks)
    result, input_token, output_token = results[0]
    print(result)
    print(input_token)
    print(output_token)
# Out:
# 你好！很高兴能以数据科学专家的身份为你详细解读**数据科学（Data Science）**。
#
# 数据科学不仅仅是一个热门的职业头衔，它更是当今数字时代的核心驱动力。为了让你全面理解，我将从**定义、核心构成、工作流程、关键技术、应用场景以及未来趋势**六个维度进行深度剖析。
#
# ---
#
# ### 1. 什么是数据科学？（核心定义）
#
# 用最通俗的话来说，**数据科学是从数据中提取知识、洞察和价值的过程。**
#
# 它是一门**交叉学科**，融合了统计学、计算机科学、数学以及特定领域的专业知识。如果把数据比作“原油”，那么数据科学就是“炼油厂”，通过复杂的工艺将其提炼成可以驱动商业决策、科学发现或技术创新的“燃料”。
#
# **专家视角的补充：**
# 很多人误以为数据科学就是“写代码”或“做预测”。其实，数据科学的本质是**解决不确定性**。它利用数据来回答：“发生了什么？”（描述性）、“为什么发生？”（诊断性）、“将来会发生什么？”（预测性）以及“我们该怎么做？”（指导性）。
#
# ---
#
# ### 2. 数据科学的“三根支柱”
#
# 要成为一名合格的数据科学家，必须掌握以下三个领域的知识，缺一不可：
#
# 1.  **数学与统计学（The Math & Stats）**
#     *   **作用：** 提供理论基础。没有统计推断，模型就是瞎猜；没有线性代数，深度学习无法运行。
#     *   **关键概念：** 概率论、假设检验、回归分析、贝叶斯定理、矩阵运算。
# 2.  **计算机科学（Computer Science）**
#     *   **作用：** 提供工具和能力。数据量太大，人脑无法处理，必须依靠计算机算法和架构。
#     *   **关键概念：** 编程语言（Python/R）、数据结构、算法复杂度、数据库管理、分布式计算。
# 3.  **领域知识（Domain Knowledge）**
#     *   **作用：** 提供业务语境。同样的数据，在金融、医疗和电商中的含义完全不同。不懂业务，模型再准也是垃圾（Garbage In, Garbage Out）。
#     *   **关键概念：** 行业逻辑、业务指标、合规性（如 GDPR）、数据伦理。
#
# ---
#
# ### 3. 数据科学的标准工作流程
#
# 数据科学不是“黑盒”，它遵循一套严谨的工程化流程。业界最通用的框架是 **CRISP-DM**（跨行业数据挖掘标准流程），通常包含以下六个阶段：
#
# 1.  **业务理解 (Business Understanding)：**
#     *   明确目标。例如：是为了降低客户流失率，还是为了提高广告转化率？
#     *   *专家提示：* 这一步最重要，如果目标错了，后续所有工作都是徒劳。
# 2.  **数据理解 (Data Understanding)：**
#     *   收集数据，探索数据分布，检查数据质量。
#     *   了解数据的来源、格式和潜在偏差。
# 3.  **数据准备 (Data Preparation)：**
#     *   **这是最耗时的阶段（通常占 60%-80% 的时间）。**
#     *   包括数据清洗（处理缺失值、异常值）、特征工程（Feature Engineering，即创造新的变量让模型更好用）、数据转换。
# 4.  **建模 (Modeling)：**
#     *   选择合适的算法（如决策树、随机森林、神经网络）。
#     *   训练模型，调整超参数，防止过拟合。
# 5.  **评估 (Evaluation)：**
#     *   验证模型是否满足业务目标。
#     *   不仅看准确率（Accuracy），还要看召回率、F1 分数、业务 ROI 等。
# 6.  **部署 (Deployment)：**
#     *   将模型集成到生产环境中，使其能实时处理新数据。
#     *   监控模型性能，防止“模型漂移”（Model Drift）。
#
# ---
#
# ### 4. 关键技术栈与工具
#
# 作为专家，你需要熟悉以下工具组合：
#
# *   **编程语言：**
#     *   **Python：** 绝对的主流，生态最丰富（Pandas, NumPy, Scikit-learn）。
#     *   **R：** 在统计分析和学术研究中非常强大。
#     *   **SQL：** 与数据库交互的必备技能，必须精通。
# *   **机器学习与深度学习框架：**
#     *   **传统 ML：** Scikit-learn, XGBoost, LightGBM。
#     *   **深度学习：** TensorFlow, PyTorch, Keras。
# *   **大数据处理：**
#     *   Hadoop, Spark (处理 TB/PB 级数据)。
# *   **数据可视化：**
#     *   Matplotlib, Seaborn (Python 绘图)。
#     *   Tableau, PowerBI (商业报表)。
# *   **云平台：**
#     *   AWS, Google Cloud, Azure (提供算力与存储)。
#
# ---
#
# ### 5. 数据科学的主要任务类型
#
# 根据目标不同，数据科学工作通常分为四类：
#
# 1.  **描述性分析 (Descriptive Analytics)：**
#     *   *问题：* 上个月销售额是多少？
#     *   *手段：* 报表、仪表盘。
# 2.  **诊断性分析 (Diagnostic Analytics)：**
#     *   *问题：* 为什么上个月销售额下降了？
#     *   *手段：* 下钻分析、相关性分析。
# 3.  **预测性分析 (Predictive Analytics)：**
#     *   *问题：* 下个月销售额会是多少？客户会流失吗？
#     *   *手段：* 回归模型、时间序列分析、分类模型。
# 4.  **规范性分析 (Prescriptive Analytics)：**
#     *   *问题：* 为了提升销售额，我们应该降价还是打广告？
#     *   *手段：* 优化算法、强化学习、模拟仿真。
#
# ---
#
# ### 6. 数据科学与相关职业的区别
#
# 这是一个常见的误区，我们需要厘清：
#
# *   **数据分析师 (Data Analyst)：** 侧重于**过去**和**现在**。主要做报表、可视化、SQL 查询，回答“发生了什么”。
# *   **数据工程师 (Data Engineer)：** 侧重于**管道**。负责搭建数据仓库、清洗管道、确保数据流动顺畅，是数据科学的“基建工人”。
# *   **数据科学家 (Data Scientist)：** 侧重于**未来**。侧重于建模、算法、预测和解决复杂问题，是数据科学的“建筑师”。
#
# ---
#
# ### 7. 现实世界中的应用案例
#
# 数据科学已经渗透到我们生活的方方面面：
#
# *   **推荐系统：** 抖音、Netflix、淘宝的“猜你喜欢”，基于协同过滤和深度学习。
# *   **金融风控：** 银行利用数据科学识别信用卡欺诈，评估贷款违约风险。
# *   **医疗健康：** 利用影像识别辅助医生诊断癌症，利用电子病历预测疾病爆发。
# *   **自动驾驶：** 特斯拉等公司利用传感器数据训练神经网络，实现车辆感知和决策。
# *   **自然语言处理 (NLP)：** 翻译软件、智能客服、情感分析。
#
# ---
#
# ### 8. 挑战与未来趋势
#
# 作为专家，我必须提醒你关注当前的挑战：
#
# 1.  **数据隐私与伦理：** 随着 GDPR 等法规出台，如何在利用数据的同时保护隐私是核心议题。
# 2.  **算法偏见 (Bias)：** 如果训练数据本身带有歧视（如种族、性别），模型会放大这种不公。
# 3.  **可解释性 (Explainability)：** 深度学习模型往往是“黑盒”，在医疗和司法领域，我们需要知道模型*为什么*做出这个决定。
# 4.  **生成式 AI (AIGC) 的冲击：** 大模型（LLM）正在改变数据科学的工作流。以前需要大量特征工程，现在可能通过 Prompt Engineering 直接获取洞察。
#
# ### 总结
#
# **数据科学不仅仅是技术，更是一种思维方式。**
#
# 它要求你具备**好奇心**（对数据背后的故事感兴趣）、**严谨性**（对统计结果负责）和**商业敏感度**（对价值负责）。在数据驱动决策的今天，数据科学是连接“数据”与“智慧”的桥梁。
#
# 如果你决定投身这个领域，请记住：**最好的数据科学家，不是代码写得最快的人，而是最能提出好问题并找到答案的人。**
#
# 希望这份详细的讲解能帮助你建立起对数据科学的宏观认知！如果有具体想深入的技术点，欢迎继续提问。
# 27
# 2947
